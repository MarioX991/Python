# %% [markdown]
# # MatPlotlib

# %%
# import matplotlib package

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Setting the style
#We will used the plt.style to choose appropriate style for our figures.

plt.style.use("classic")

# %%
# ploting 
x=np.linspace(0,10,100)
fig= plt.figure()
plt.plot(x,np.sin(x),":")

plt.plot(x,np.cos(x),"--")

# %% [markdown]
# #### Saving figure file
#
# One nice teatures Matplotlib us the ability to save figures in the wide variety of formats. You can  save a figure using __savefig()__ command.

# %%
#save previous figure as a PNG file, we run this:

fig.savefig("my_figure.png")

# %%
# We now have a fig called "my_figure.png" in the current working directory:

# %% [markdown]
# ## Tow interface for Price of One
# ### MATLAB style interface
# Matplotlib was originally written as Python alternative for MATLAB user, and much of its sytax reflects that fact.

# %%
plt.figure() # create a plot figure

# %%
# Create the first of two panels and se t curretn axis
plt.subplot(2,1,1) #(row, columns, panel number)
plt.plot(x,np.sin(x))
#create the second panel anse set current axis
plt.subplot(2,1,2) 
plt.plot(x,np.cos(x))

# %% [markdown]
# ### Object-orienter interface
#
# The OOP interface is available for these more complicated situation, and for when you want more control over your figure. Rather that dependint on some notion of an "active" figure or axis, in oop interface the plotting fictions are __methods__ of explicit __Figure__ and __Axes__ object. To recreate the previous plot using the style of plotting, you might do to following:

# %%
# First create a girid of plots
# ax will be array of two Axes object
fig, (ax)= plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x))

# %% [markdown]
# ### Simple line plot
#
# Perhaps the simplest of all plots is the visualization of a single function _y=f(x)_. Here we will take a first look at create a simple plot ot this type.

# %%
plt.style.use("seaborn-darkgrid")

# %% [markdown]
# For all Matplotli plots, we start by creating a figure and an axes. In simle form, a figure and axis can be created as follows:

# %%
fig=plt.figure()
ax=plt.axes()

#fig, ax=plt.subplots(1)
#ax.plot(x,np.sin(x))
#ax.plot(x,np.cos(x))

# %% [markdown]
# in Matplotlib, the __figure__ can be thought of as a single container that contains all of object representing:
#       - axes
#       - graphic
#       - text
#       - lables
#
# The __axes__ is what we see above: a bounding box with ticks and labels, wich will eventually cantain the plot elements that make up our visualization.

# %%
fig = plt.figure()
ax= plt.axes()

# %%
x=np.linspace(0,10,100)
ax.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x))

# %% [markdown]
# If e want to create a singe figure with multiple lines, we can simply call the plot function multiple times:

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %% [markdown]
# ## Adjusting the Plot: Line colors and style
#
# The first adjustment you minght wish to make to a plot is to control the line colors and styles. The __plt.plot()__ fucntion take additional arguments that can be used to specify these.
# To adjust color you can used __color__ keyword, which accepts a string argument representing virtually any inaginable colors.
# __ Colors can be specify in a variety of ways__:

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %% [markdown]
# Similarly, you can adjust the line style using __linestyle__ keyword.

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# %%
#short way
plt.plot(x, x + 4, linestyle='-') # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':'); # dotted

# %% [markdown]
# ## Adjasting the plot: Axes Limits
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control. The most basic way to adjast axis limits is to use the __plt.xlim()__ and __plt.ylim()__ methods:

# %%
plt.plot(x,np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)

# now we will see ho2 to put this all together
# Out:
# (-1.5, 1.5)

# %% [markdown]
# The useful related method is __plt.axis()__ hi allows as to set the x and y limits with single call, by passing a list that specifies __[xmin,xmax,ymin,ymax]__

# %%
plt.plot(x,np.sin(x))
plt.axis([-1,11,-1.5,1.5])
# Out:
# [-1, 11, -1.5, 1.5]

# %% [markdown]
# plt.axis() methos goes even beyond this, allowing you to do things like automatically tighten the bounds around the current plot.

# %%
plt.plot(x,np.sin(x))
plt.axis("tight")
# Out:
# (0.0, 10.0, -0.9993845576124357, 0.9996923408861117)

# %%
plt.plot(x,np.sin(x))
plt.axis("equal")
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %% [markdown]
# ### Lebeling plots
#
# As the last piece ot this section, we'll brifly look at he labeling of plots:
#      - titles
#      - axes
#      - labels
#      - legends

# %%
plt.plot(x, np.sin(x))
plt.axis("equal")
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(s)")
# Out:
# Text(0, 0.5, 'sin(s)')

# %% [markdown]
# When multiple line are being show within a singe axes, it can be useful to create a plot legend that labels each line type. It is done via the __plt.legend()__ method.

# %%
plt.plot(x,np.sin(x),linestyle="-.",color="blue", label="sin(x)")
plt.plot(x,np.cos(x),linestyle="-",color="red", label="cos(x)")
plt.axis("equal")
plt.legend()

# %% [markdown]
# # OOP about this staff above:
#  Whle most plt function transalte directly to ax method such as plt.plot() -> ax.plt(), plt.legend() -> ax.legend().. For transitioning to OO method meke following change:
#
#   * plt.xlabel() - ax.set_xlabel()
#   * plt.ylabel() - ax.set_ylabel()
#   * plt.xlim() - ax.set_xlim()
#   * plt.ylim() - ax.set_ylim()
#   * plt.title() - ax.set_title()
#
#
# In the oo interface to plotting, taher than calling these functions individually it is often more convenient to use the __ax.set()__ method to set all these properties once:

# %%
ax=plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10) ,ylim=(-2, 2),
    xlabel="x",ylabel="sin(x)",
    title="A simple plot");

# %% [markdown]
# ### Simple scatter plots

# %% [markdown]
# Anather commonly used plot type is the simple scatter plot, a close cousin of the line plot. Instand od point joined by line segments here the points are represented individuallywith a dot, circle or other shape.

# %% [markdown]
# ### Scatter plots with plt.plot

# %%
plt.style.use("seaborn-darkgrid")
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y,"*",color="black");

# %% [markdown]
# Most common used marker for ploting character we will represent here:

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
     plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))

# %% [markdown]
# For more possibilities , these caracter code can be used together wit line and color to plot points along with a line connecting them

# %%
plt.plot(x,y,"-ok")
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# Additional keyword arguments to plt.plot specify a wide range of properties of the lines and markers

# %%
plt.plot(x,y,"-p",color="green",
        markersize=12,
        linewidth=3,
        markerfacecolor="white",
        markeredgecolor="grey",
        markeredgewidth=2)
plt.ylim(-1.2,1.2);

# %% [markdown]
# ### Scatter Plots with plt.scatter
#
# A Secont more powerful method pf creating scatter plots is the plt.scatter function, which can be used very similatlyto the plt.plot function

# %%
plt.scatter(x,y,marker="o")

# %% [markdown]
# The primary difference of plt.scatter nad plt.plot is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, ets) can be individually controlled or mapped to data.
#
# __alpha__ keyword used in order to better see the overlapping result

# %%
rng=np.random.RandomState(0)
x=rng.randn(100)
y=rng.randn(100)
colors=rng.rand(100)
size=1000 * rng.rand(100)


plt.scatter(x,y,c=colors,s=size, alpha=0.3, cmap="viridis")
plt.colorbar();

# %% [markdown]
# Color argument is automatically mapped to a color scale (shown here by the __colorbar()__ command and the size argument is given in pixels

# %% [markdown]
# # Visualizing Error
#
# A basic errorbar can be created a single Matpotlib function call

# %%
plt.style.use("seaborn-darkgrid")
x=np.linspace(0,10,50)
dy=0.8
y=np.sin(x)+dy*np.random.randn(50)

plt.errorbar(x,y,yerr=dy,fmt=".k");

# %% [markdown]
# Here the fmt is format code controlling the appearance of lines and points, and has the same syntax as the shorthand used in plt.plot
# In addition ti these basic options, the errorbar fucntion has many options to finetune the output.
# Often is very helpful, especially in crowded plots , to make the errorbars lighter than the points themselves

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
 ecolor='lightgray', elinewidth=3, capsize=0);

# %% [markdown]
# ## Histograms, Binnings, and Density
#
# A simple histogram cen be great first step in understanding a dataset.

# %%
data=np.random.randn(1000)
plt.hist(data,alpha=0.5);

# %% [markdown]
# The __hist()__ function has many options to tune the calculation and the display; here is example for more customized histomgram

# %%
plt.hist(data, bins=30, normed=True, alpha=0.5,
        histtype="stepfilled",color="steelblue",
        edgecolor="none");

# %% [markdown]
# This combination of histtype="stepfilled" and "alpha" transparency is very usefull when comparing histogram sof several distributions

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# ## Two dimesnional Histogram and Binnings
#
# Just as we create histograms in one dimension by dividing the number line into bins,
# we can also create histograms in two dimensions by dividing points among twodimensional bins
#  We’ll take a brief look at several ways to do this here. We’ll start by
# defining some data—an x and y array drawn from a multivariate Gaussian
# distribution:

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %% [markdown]
# ### plt.hist2d: Two-dimensional histogram
#
# one streightforward way to plot two dimesnional histogra is to udes matlotlib plt.hist2d function

# %%
plt.hist2d(x,y,bins=30,cmap="Blues");
cb=plt.colorbar()
cb.set_label("count in bin")

# %% [markdown]
# ## plt.hexbin: Hexagonal binnings
#
# The two-dimensional histogram creates a tessellation of squares across the axes. Another natural shape for such a tessellation is regular hexagon. For this purpose, Matplotlib provides the plt.hexbin rutine:

# %%
plt.hexbin(x,y,gridsize=25, cmap="Blues")
cb=plt.colorbar(label="count in bins")

# %% [markdown]
# ## Kernel density estimation
#
# Another common method of evaluating densities in multiple dimensions is _kernel desnsity estimation(KDE)_.

# %%
from scipy.stats import gaussian_kde

# fit an array of size [Ndim, Nsamples]
data = np.vstack([x, y])
kde = gaussian_kde(data)
# evaluate on a regular grid
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# %%
# Plot the result as an image
plt.imshow(Z.reshape(Xgrid.shape),
origin='lower', aspect='auto',
extent=[-3.5, 3.5, -6, 6],
cmap='Blues')
cb = plt.colorbar()
cb.set_label("density")

# %% [markdown]
# ## Custimizing Plot Legends
#
# Plot legends give meaning to a visualization, assigning labels to the various plot ele‐
# ments. We previously saw how to create a simple legend; here we’ll take a look at cus‐
# tomizing the placement and aesthetics of the legend in Matplotlib.
# The simplest legend can be created with the plt.legend() command, which auto‐
# matically creates a legend for any labeled plot elements

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %% [markdown]
# We can use the ncol command to specify the number of columns in the legend

# %%
ax.legend(frameon=False, loc='lower center', ncol=2)
fig

# %% [markdown]
# We can use a rounded box (fancybox) or add a shadow, change the transparency
# (alpha value) of the frame, or change the padding around the text

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %% [markdown]
# ## Multiple Subplots
#
# Sometimes it is helpful to compare different views of data side by side. To this end,
# Matplotlib has the concept of subplots: groups of smaller axes that can exist together
# within a single figure. These subplots might be insets, grids of plots, or other more
# complicated layouts.

# %% [markdown]
# ## plt.axes: Subplots by Hand
#
# The most basic method of creating an axes is to use the plt.axes function. As we’ve
# seen previously, by default this creates a standard axes object that fills the entire fig‐
# ure. plt.axes also takes an optional argument that is a list of four numbers in the
# figure coordinate system. These numbers represent [bottom, left, width,
# height] in the figure coordinate system, which ranges from 0 at the bottom left of the
# figure to 1 at the top right of the figure.

# %%
ax1 = plt.axes() # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %% [markdown]
# The equivalent of this command within the object-oriented interface is
# fig.add_axes(). Let’s use this to create two vertically stacked axes

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                 ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                    ylim=(-1.2, 1.2))
x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %% [markdown]
# ## plt.subplot: Simple Grids of Subplots
#
# Aligned columns or rows of subplots are a common enough need that Matplotlib has
# several convenience routines that make them easy to create. The lowest level of these
# is plt.subplot(), which creates a single subplot within a grid. As you can see, this
# command takes three integer arguments—the number of rows, the number of col‐
# umns, and the index of the plot to be created in this scheme, which runs from the
# upper left to the bottom right

# %%
for i in range(1, 7):
     plt.subplot(2, 3, i)
     plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %% [markdown]
# The command __plt.subplots_adjust__ can be used to adjust the spacing between
# these plots.

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
 fontsize=18, ha='center')

# %% [markdown]
# We’ve used the hspace and wspace arguments of __plt.subplots_adjust__, which spec‐
# ify the spacing along the height and width of the figure

# %% [markdown]
# ## plt.subplots: The Whole Grid in One Go
#
# The approach just described can become quite tedious when you’re creating a large
# grid of subplots, especially if you’d like to hide the x- and y-axis labels on the inner
# plots. For this purpose, plt.subplots() is the easier tool to use (note the s at the end
# of subplots). Rather than creating a single subplot, this function creates a full grid of
# subplots in a single line, returning them in a NumPy array. The arguments are the
# number of rows and number of columns, along with optional keywords sharex and
# sharey, which allow you to specify the relationships between different axes.

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
     fontsize=18, ha='center')
fig
